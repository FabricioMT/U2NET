# %%
import os, shutil, cv2
import pathlib as pl
import numpy as np

def createMask(img):
	image = cv2.imread(img, cv2.IMREAD_UNCHANGED)
	image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
	ret, image_edges = cv2.threshold(image_gray, 0, 255, cv2.THRESH_BINARY)
	mask = np.zeros(image_gray.shape, np.float32)
	mask.fill(0)

	contours, hierarchyct = cv2.findContours(image=image_edges,mode=cv2.RETR_EXTERNAL,method=cv2.CHAIN_APPROX_NONE)
	#thickness=-1
	cv2.drawContours(image=mask,contours=contours,contourIdx=-1,color=(255,255,255),thickness=-1)
	return mask

def createContours(img):
    image = cv2.imread(img, cv2.IMREAD_UNCHANGED)
    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ret, image_edges = cv2.threshold(image_gray, 0, 255, cv2.THRESH_BINARY)
    mask = np.zeros(image_gray.shape, np.float32)
    mask.fill(255)

    contours, hierarchyct = cv2.findContours(image=image_edges,mode=cv2.RETR_EXTERNAL,method=cv2.CHAIN_APPROX_NONE)
    

    pixel_count = []
    for component in contours: pixel_count.append(len(component))
    max_pixel_ct = pixel_count.index(max(pixel_count))

    cv2.drawContours(image=mask,contours=contours[max_pixel_ct],contourIdx=-1,color=(0,0,0),thickness=1)
    #thickness=-1
    return mask

def threshold(img):
	src = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
	th, dst = cv2.threshold(src, 0, 255, cv2.THRESH_BINARY)
	return dst

def createMaskFolder():
	srcPath = r"D:\Data_set_Inits\GreyV2\Grey_correct\mask" + os.sep
	destPath = r"D:\Data_set_Inits\GreyV2\Grey_correct\mask2" + os.sep
	files = os.listdir(srcPath)
	n = 0
	finish = len(files)
	print('Total Images :',finish)
	for num, file in enumerate(files):
		count = f"GG-{str(n)}.JPG"
		if n == finish: return 0
		filename = pl.PurePath(file[:0]+count).name
		if str(count) == filename:
			mask = createMask(srcPath + filename)
			cv2.imwrite(destPath + count,mask)
			print("Image Mask Create ",srcPath + filename)
			cv2.waitKey(0)
			cv2.destroyAllWindows()
			
		n = n+1

def createMaskFolderaaa():
	srcPath = r"D:\DATASETS\GreyV3\mask" + os.sep
	destPath = r"D:\DATASETS\GreyV3\maask" + os.sep
	files = os.listdir(srcPath)
	print(files)
	n = 0
	finish = len(files)
	print('Total Images :',finish)
	try:
		for num, file in enumerate(files):
			if n == finish: return 0
			print(file)
			mask = createMask(srcPath + file)
			cv2.imwrite(destPath + file,mask)
			#cv2.imshow("mask",mask)
			print("Image Mask Create ",srcPath + file)
			cv2.waitKey(0)
			cv2.destroyAllWindows()
				
			n = n+1
	except Exception or TypeError:
		createMaskFolderaaa()
		raise Exception("Save error")

if __name__ == '__main__':
	#createMaskFolder()
	createMaskFolderaaa()
	#mask = createContours(r"D:\Data_set_Inits\GreyV3\pre\00042295034.jpg.png")
	# contour = createContours(r"C:\Users\fabri\OneDrive\Área de Trabalho\Py Script\U-2-Net\PicStone-Bg-Output\8cbe74bd-391c-4b70-a33f-c2a388b46be6.png")
	# mask2 = createMask(r"C:\Users\fabri\OneDrive\Área de Trabalho\RedesNeurais\rembg-test\to\output\2.png")
	# contour2 = createContours(r"C:\Users\fabri\OneDrive\Área de Trabalho\RedesNeurais\rembg-test\to\output\2.png")
	#cv2.imshow("mask",mask)
	#cv2.imwrite("G-1720.JPG",mask)
	# cv2.imshow("mask2",mask2)
	# cv2.imshow("contour2",contour)
	cv2.waitKey(0)
	cv2.destroyAllWindows()

# %% [markdown]
# TESTE

# %%
import os, shutil, cv2
import pathlib as pl
import numpy as np

def createMask(img):
	image = cv2.imread(img, cv2.IMREAD_UNCHANGED)
	image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
	ret, image_edges = cv2.threshold(image_gray, 0, 255, cv2.THRESH_BINARY)
	mask = np.zeros(image_gray.shape, np.float32)
	mask.fill(0)

	contours, hierarchyct = cv2.findContours(image=image_edges,mode=cv2.RETR_EXTERNAL,method=cv2.CHAIN_APPROX_NONE)
	#thickness=-1
	cv2.drawContours(image=mask,contours=contours,contourIdx=-1,color=(255,255,255),thickness=-1)
	return mask

def createContours(img):
	image = cv2.imread(img, cv2.IMREAD_UNCHANGED)
	image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
	ret, image_edges = cv2.threshold(image_gray, 0, 255, cv2.THRESH_BINARY)
	mask = np.zeros(image_gray.shape, np.float32)
	mask.fill(255)

	contours, hierarchyct = cv2.findContours(image=image_edges,mode=cv2.RETR_EXTERNAL,method=cv2.CHAIN_APPROX_NONE)
	#thickness=-1
	cv2.drawContours(image=mask,contours=contours,contourIdx=-1,color=(0,0,0),thickness=1)
	return mask

def threshold(img):
	src = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
	th, dst = cv2.threshold(src, 0, 255, cv2.THRESH_BINARY)
	return dst

def createMaskFolder():
	srcPath = r"D:\Data_set_Inits\Grey init\Nova pasta\tes2" + os.sep
	destPath = r"D:\Data_set_Inits\Grey init\Nova pasta\mask" + os.sep
    
	files = os.listdir(srcPath)
	find = [pl.PurePath(find).name.split('-PhotoRoom.png-PhotoRoom')[0] for find in files]
	
	#print(find)
	print(len(files))
	n = 0
	finish = len(files)
	print('Total Images :',finish)

	for file in files:
		count = f"{str((find[0+n]))}-PhotoRoom.png-PhotoRoom.png"
		maskName = f"{str((find[0+n]))}.JPG"
		filename = pl.PurePath(file[:0]+count).name
		print(srcPath + filename)
		mask = createMask(srcPath + filename)
		cv2.imwrite(destPath + maskName,mask)
		cv2.waitKey(0)
		cv2.destroyAllWindows()
		n = n+1

if __name__ == '__main__':
	createMaskFolder()

	# mask = createMask(r"D:\Data_set_Inits\Grey init\Nova pasta\test\aaaa.png")
	# # contour = createContours(r"C:\Users\fabri\OneDrive\Área de Trabalho\Py Script\U-2-Net\PicStone-Bg-Output\8cbe74bd-391c-4b70-a33f-c2a388b46be6.png")
	# # mask2 = createMask(r"C:\Users\fabri\OneDrive\Área de Trabalho\RedesNeurais\rembg-test\to\output\2.png")
	# # contour2 = createContours(r"C:\Users\fabri\OneDrive\Área de Trabalho\RedesNeurais\rembg-test\to\output\2.png")
	# cv2.imshow("mask",mask)
	# # cv2.imwrite("contour.png",contour)
	# # cv2.imshow("mask2",mask2)
	# # cv2.imshow("contour2",contour)
	# cv2.waitKey(0)
	# cv2.destroyAllWindows()
# Out:
# 53
# Total Images : 53
# D:\Data_set_Inits\Grey init\Nova pasta\tes2\-10-PhotoRoom.png-PhotoRoom.png
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\fabri\OneDrive\Área de Trabalho\PyScript\U2NET\app\maskGenerate.ipynb Cell 3 in 5
#      <a href='vscode-notebook-cell:/c%3A/Users/fabri/OneDrive/%C3%81rea%20de%20Trabalho/PyScript/U2NET/app/maskGenerate.ipynb#W2sZmlsZQ%3D%3D?line=55'>56</a> 		n = n+1
#      <a href='vscode-notebook-cell:/c%3A/Users/fabri/OneDrive/%C3%81rea%20de%20Trabalho/PyScript/U2NET/app/maskGenerate.ipynb#W2sZmlsZQ%3D%3D?line=57'>58</a> if __name__ == '__main__':
# ---> <a href='vscode-notebook-cell:/c%3A/Users/fabri/OneDrive/%C3%81rea%20de%20Trabalho/PyScript/U2NET/app/maskGenerate.ipynb#W2sZmlsZQ%3D%3D?line=58'>59</a> 	createMaskFolder()
#
# c:\Users\fabri\OneDrive\Área de Trabalho\PyScript\U2NET\app\maskGenerate.ipynb Cell 3 in 5
# ...

# %%
# Python code for Background subtraction using OpenCV
import numpy as np
import cv2
  
cap = cv2.imread(r"C:\Users\fabri\OneDrive\Área de Trabalho\PyScript\U2NET\input_folder\input-images\00043634059.jpg", cv2.IMREAD_UNCHANGED)
fgbg = cv2.BackgroundSubtractor()
  
ret, frame = cap.read()

fgmask = fgbg.apply(frame)

cv2.imshow('fgmask', fgmask)
cv2.imshow('frame',frame )

cap.release()
cv2.destroyAllWindows()

# %%
import glob
import os
import warnings

import torch
from PIL import Image
from skimage import io
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms

from app.data_loader import RescaleT
from app.data_loader import SalObjDataset
from app.data_loader import ToTensorLab
from app.folder_paths import (input_images_folder, output_result_mask, model_in_work)
from app.model import U2NET

warnings.simplefilter("ignore", UserWarning)

# --------- 3. model define ---------

net = U2NET(3, 1)
if torch.cuda.is_available():
    net.load_state_dict(torch.load(model_in_work))
    net.cuda()
else:
    net.load_state_dict(torch.load(model_in_work, map_location=torch.device('cpu')))


def normPRED(d):
    ma = torch.max(d)
    mi = torch.min(d)

    dn = (d - mi) / (ma - mi)

    return dn

def save_output(image_name, pred,d_dir):
    predict = pred
    predict = predict.squeeze()
    predict_np = predict.cpu().data.numpy()

    im = Image.fromarray(predict_np * 255).convert('RGB')
    img_name = image_name.split(os.sep)[-1]
    image = io.imread(image_name)
    imo = im.resize((image.shape[1], image.shape[0]), resample=Image.Resampling.LANCZOS)

    aaa = img_name.split(".")
    bbb = aaa[0:-1]
    imidx = bbb[0]
    for i in range(1, len(bbb)):
        imidx = imidx + "." + bbb[i]

    imo.save(d_dir + imidx + '.JPG')


def mask():
    # --------- 1. get image path and name ---------
    image_dir = os.path.join(input_images_folder)
    prediction_dir = os.path.join(output_result_mask)
    img_slot_0 = []
    img_name_list = glob.glob(image_dir + os.sep + '*')
    img_slot_0 = [img_name_list[0]]

    # 1. dataloader
    test_salobj_dataset = SalObjDataset(img_name_list=img_name_list,
                                        lbl_name_list=[],
                                        transform=transforms.Compose([RescaleT(320),
                                                                      ToTensorLab(flag=0)])
                                        )
    test_salobj_dataloader = DataLoader(test_salobj_dataset,
                                        batch_size=1,
                                        shuffle=False,
                                        num_workers=1)

    net.eval()
    for i_test, data_test in enumerate(test_salobj_dataloader):

        inputs_test = data_test['image']
        inputs_test = inputs_test.type(torch.FloatTensor)

        if torch.cuda.is_available():
            inputs_test = Variable(inputs_test.cuda())
        else:
            inputs_test = Variable(inputs_test)

        d1, d2, d3, d4, d5, d6, d7 = net(inputs_test)

        # normalization
        pred = d1[:, 0, :, :]
        pred = normPRED(pred)

        save_output(img_name_list[i_test], pred, prediction_dir)

        del d1, d2, d3, d4, d5, d6, d7
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\fabri\OneDrive\Área de Trabalho\PyScript\U2NET\app\maskGenerate.ipynb Cell 5 in 1
#       <a href='vscode-notebook-cell:/c%3A/Users/fabri/OneDrive/%C3%81rea%20de%20Trabalho/PyScript/U2NET/app/maskGenerate.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> from torch.utils.data import DataLoader
#      <a href='vscode-notebook-cell:/c%3A/Users/fabri/OneDrive/%C3%81rea%20de%20Trabalho/PyScript/U2NET/app/maskGenerate.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> from torchvision import transforms
# ---> <a href='vscode-notebook-cell:/c%3A/Users/fabri/OneDrive/%C3%81rea%20de%20Trabalho/PyScript/U2NET/app/maskGenerate.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a> from app.data_loader import RescaleT
# ...

# %%
import os

import cv2
import numpy as np
from PIL import Image as Img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img

from app.folder_paths import (output_result_mask, input_images_folder)


def remove(input_folder, output_folder):
    image_dir = os.path.join(os.getcwd(), input_folder)
    bg_dir = os.path.join(os.getcwd(), output_folder + os.sep)
    input_img = os.listdir(image_dir)[0]
    file = os.listdir(output_result_mask)[0]
    img_name = input_img[:-4]
    THRESHOLD = 0.9
    RESCALE = 255

    output = load_img(output_result_mask + file)
    out_img = img_to_array(output)
    out_img /= RESCALE

    out_img[out_img > THRESHOLD] = 1
    out_img[out_img <= THRESHOLD] = 0

    shape = out_img.shape
    a_layer_init = np.ones(shape=(shape[0], shape[1], 1))
    mul_layer = np.expand_dims(out_img[:, :, 0], axis=2)
    a_layer = mul_layer * a_layer_init
    rgba_out = np.append(out_img, a_layer, axis=2)

    input = load_img(input_images_folder + input_img)
    inp_img = img_to_array(input)
    inp_img /= RESCALE

    a_layer = np.ones(shape=(shape[0], shape[1], 1))
    rgba_inp = np.append(inp_img, a_layer, axis=2)

    rem_back = (rgba_inp * rgba_out)
    rem_back_scaled = rem_back * RESCALE

    # OUTPUT RESULTS

    inp_img *= RESCALE
    inp_img = np.append(inp_img, RESCALE * a_layer, axis=2)
    inp_img = cv2.resize(inp_img, (int(shape[1] / 3), int(shape[0] / 3)))
    rem_back = cv2.resize(rem_back_scaled, (shape[1], shape[0]))
    result_img = Img.fromarray(rem_back.astype('uint8'), 'RGBA')
    result_img.save(bg_dir + f'{img_name}.png')


if __name__ == "__main__":
    remove()

# %%
import cv2
import numpy as np

# Leitura da imagem
img = cv2.imread(r"C:\Users\fabri\OneDrive\Área de Trabalho\PyScript\U2NET\input_folder\input-images\00048939021.JPG")

# Criação da máscara
mask = np.zeros_like(img[:,:,0]) # Cria uma matriz de zeros com as mesmas dimensões da imagem
pts = np.array([[100,100],[300,100],[300,300],[100,300]], dtype=np.int32) # Definição dos pontos para criar a forma da máscara
cv2.fillPoly(mask, [pts], (255,255,255)) # Preenchimento da forma com a cor branca
cv2.imshow('Imagem com a Máscara Aplicada', mask)
# Aplicação da máscara na imagem original
masked_image = cv2.bitwise_and(img, img, mask=mask)

# Exibição da imagem com a máscara aplicada
cv2.imshow('Imagem com a Máscara Aplicada', masked_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import pyautogui
import cv2
import numpy as np

backpack_region = (100, 100, 400, 400) # define a região da tela onde a backpack é exibida
backpack_image = pyautogui.screenshot(region=backpack_region)
backpack_image.save('backpack.png') # salva a imagem da backpack em um arquivo

backpack_image = cv2.imread('backpack.png')
backpack_gray = cv2.cvtColor(backpack_image, cv2.COLOR_BGR2GRAY)

_, thresh = cv2.threshold(backpack_gray, 200, 255, cv2.THRESH_BINARY)
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    cv2.rectangle(backpack_image, (x, y), (x + w, y + h), (0, 255, 0), 2)

cv2.imshow('Backpack', backpack_image)
cv2.waitKey()
# Out:
# -1

# %%
import os
from unidecode import unidecode

# %%
image = r"D:\DATASETS\data_test_G_Y\image/" 
mask = r"D:\DATASETS\data_test_G_Y\mask/"

x = ImageMaskDataset(image,mask)
print(x.old_name())
print(x.new_name())
#print(x.mask_files)
# Out:
# {'old_image_name': '0.JPG', 'old_mask_name': '0.JPG'}
# 0
# 5

# %%
def check(inputs,output):
    image = os.listdir(inputs)[0]
    mask = os.listdir(output)[0]

    img_name = image[:-4]
    mask_name = mask[:-4]


class ImageMaskDataset(object):
    def __init__(self, image_dir, mask_dir):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.image_files = os.listdir(image_dir)
        self.mask_files = os.listdir(mask_dir)


    def __call__(self):
        image = os.listdir(self.image_path)[0]
        mask = os.listdir(self.mask_path)[0]  
        img_name = image[:-4]
        mask_name = mask[:-4]
        return (img_name,mask_name)

# %%
# Out:
# 0.JPG
# 0.JPG
